# %%
import pandas as pd

data = pd.read_csv("/home/blueberry/Picsart-Academy/ML/EDA.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Product ID Product Position Promotion Product Category  \
# 0           0      185102            Aisle       Yes         clothing
# 1           1      188771            Aisle       Yes         clothing
# 2           2      180176          End-cap       Yes         clothing
# 3           3      112917            Aisle       Yes         clothing
# 4           4      192936          End-cap       Yes         clothing
#
#   Seasonal  Sales Volume                  name  price currency    terms  \
# 0      Yes          1243   BASIC PUFFER JACKET  78.99      USD  jackets
# 1       No          1429         TUXEDO JACKET  14.99      USD  jackets
# 2      Yes          1168  SLIM FIT SUIT JACKET  71.95      USD  jackets
# 3       No          1348   STRETCH SUIT JACKET  30.99      USD  jackets
# 4      Yes          1602   DOUBLE FACED JACKET  22.99      USD  jackets
#
#   section  season    material   origin
# 0     MAN  Winter   Polyester   Brazil
# ...

# %%
data.shape
# Out:
# (20252, 15)

# %%
data.describe()
# Out:
#          Unnamed: 0     Product ID  Sales Volume         price
# count  20252.000000   20252.000000  20252.000000  20252.000000
# mean   10125.500000  208931.432303   1097.400454     41.949061
# std     5846.393162    8961.076507    298.234609     23.380960
# min        0.000000  110075.000000    518.000000     12.000000
# 25%     5062.750000  204442.750000    849.000000     23.950000
# 50%    10125.500000  209505.500000    990.000000     35.950000
# 75%    15188.250000  214568.250000   1364.250000     53.950000
# max    20251.000000  219631.000000   1940.000000    134.990000

# %%
import seaborn as sns

sns.pairplot(data)
